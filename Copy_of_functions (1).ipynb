# %% [markdown]
# #  fuctions
# 1.what is the difference between a function and a method of phython?
# # answer:
# # A function is a block of code that is defined outside a class.
# # A method is a function that is defined inside a class.
